# %%
# Task 1: Read the dataset and do data pre-processing
import numpy as np
import pandas as pd
import tensorflow
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Reading the csv file
df = pd.read_csv('sample_data/drug200.csv')

# Visualizing the 1st 5 observations
df.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  DrugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  DrugY

# %%
# Visualizing the last 5 observations
df.tail()
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 195   56   F     LOW        HIGH   11.567  drugC
# 196   16   M     LOW        HIGH   12.006  drugC
# 197   52   M  NORMAL        HIGH    9.894  drugX
# 198   23   M  NORMAL      NORMAL   14.020  drugX
# 199   40   F     LOW      NORMAL   11.349  drugX

# %%
# descriptive stat
df.describe(include='all')
# Out:
#                Age  Sex    BP Cholesterol     Na_to_K   Drug
# count   200.000000  200   200         200  200.000000    200
# unique         NaN    2     3           2         NaN      5
# top            NaN    M  HIGH        HIGH         NaN  DrugY
# freq           NaN  104    77         103         NaN     91
# mean     44.315000  NaN   NaN         NaN   16.084485    NaN
# std      16.544315  NaN   NaN         NaN    7.223956    NaN
# min      15.000000  NaN   NaN         NaN    6.269000    NaN
# 25%      31.000000  NaN   NaN         NaN   10.445500    NaN
# 50%      45.000000  NaN   NaN         NaN   13.936500    NaN
# 75%      58.000000  NaN   NaN         NaN   19.380000    NaN
# max      74.000000  NaN   NaN         NaN   38.247000    NaN

# %%
# Check the null values
df.isnull().sum()
# Out:
# Age            0
# Sex            0
# BP             0
# Cholesterol    0
# Na_to_K        0
# Drug           0
# dtype: int64

# %%
# We are not having any null values so we can skip the handling null value step.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          200 non-null    int64
#  1   Sex          200 non-null    object
#  2   BP           200 non-null    object
#  3   Cholesterol  200 non-null    object
#  4   Na_to_K      200 non-null    float64
#  5   Drug         200 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 9.5+ KB

# %%
# Finding unique category
df['Drug'].unique()
# Out:
# array(['DrugY', 'drugC', 'drugX', 'drugA', 'drugB'], dtype=object)

# %%
# Finding the count of observations based on unique value
df['Drug'].value_counts()
# Out:
# DrugY    91
# drugX    54
# drugA    23
# drugC    16
# drugB    16
# Name: Drug, dtype: int64

# %%
label_encoder = LabelEncoder() # initialize the lib
# transfrom all onjext cols with label_encoder
df['Sex'] = label_encoder.fit_transform(df['Sex'])
df['BP'] = label_encoder.fit_transform(df['BP'])
df['Cholesterol'] = label_encoder.fit_transform(df['Cholesterol'])
df['Drug'] = label_encoder.fit_transform(df['Drug'])

# %%
df.head()
# Out:
#    Age  Sex  BP  Cholesterol  Na_to_K  Drug
# 0   23    0   0            0   25.355     0
# 1   47    1   1            0   13.093     3
# 2   47    1   1            0   10.114     3
# 3   28    0   2            0    7.798     4
# 4   61    0   1            0   18.043     0

# %%
# Split the training and testing data
X = df.iloc[:,:-1]
Y = df.iloc[:,-1]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
# Task 2: Build the ANN model with (input layer, min 3 hidden layers & output layer)
# Initializing the seq model
model = Sequential()
# Adding the input layer to the model
model.add(Dense(64, activation='relu', input_dim=X_train.shape[1])) #input_dim=no. of cols in X_train
# Adding the 3 hidden layer to the model
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
# Adding output layer
total_classes = len(label_encoder.classes_) #find total classes in output
model.add(Dense(total_classes, activation='softmax')) #more than 2 difference classes in output use softmax

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 64)                384
#
#  dense_11 (Dense)            (None, 64)                4160
#
#  dense_12 (Dense)            (None, 32)                2080
#
#  dense_13 (Dense)            (None, 16)                528
#
#  dense_14 (Dense)            (None, 5)                 85
#
# =================================================================
# Total params: 7,237
# Trainable params: 7,237
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, Y_train, batch_size=32, epochs=10, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/10
# 5/5 [==============================] - 2s 45ms/step - loss: 1.4363 - accuracy: 0.4625 - val_loss: 1.5173 - val_accuracy: 0.3750
# Epoch 2/10
# 5/5 [==============================] - 0s 10ms/step - loss: 1.2807 - accuracy: 0.4750 - val_loss: 1.3864 - val_accuracy: 0.3750
# Epoch 3/10
# 5/5 [==============================] - 0s 10ms/step - loss: 1.1700 - accuracy: 0.5375 - val_loss: 1.2670 - val_accuracy: 0.5000
# Epoch 4/10
# 5/5 [==============================] - 0s 10ms/step - loss: 1.1273 - accuracy: 0.5375 - val_loss: 1.2783 - val_accuracy: 0.4500
# Epoch 5/10
# 5/5 [==============================] - 0s 11ms/step - loss: 1.0802 - accuracy: 0.5688 - val_loss: 1.2182 - val_accuracy: 0.5000
# Epoch 6/10
# 5/5 [==============================] - 0s 13ms/step - loss: 1.0498 - accuracy: 0.6125 - val_loss: 1.2078 - val_accuracy: 0.5000
# Epoch 7/10
# 5/5 [==============================] - 0s 10ms/step - loss: 1.0221 - accuracy: 0.5938 - val_loss: 1.1977 - val_accuracy: 0.5000
# Epoch 8/10
# 5/5 [==============================] - 0s 10ms/step - loss: 1.0087 - accuracy: 0.6125 - val_loss: 1.1690 - val_accuracy: 0.5000
# Epoch 9/10
# 5/5 [==============================] - 0s 10ms/step - loss: 0.9726 - accuracy: 0.6125 - val_loss: 1.1599 - val_accuracy: 0.5000
# Epoch 10/10
# 5/5 [==============================] - 0s 9ms/step - loss: 0.9717 - accuracy: 0.6062 - val_loss: 1.1637 - val_accuracy: 0.5000

# %%
_, accuracy = model.evaluate(X_test, Y_test)
accuracy
# Out:
# 2/2 [==============================] - 0s 7ms/step - loss: 1.1637 - accuracy: 0.5000
# 0.5

# %%
# Task 3: Test the model with random data
Y_pred = model.predict(X_test)
l=[]
for arr in Y_pred:
  predicted_class = np.argmax(arr)
  predicted_drug = label_encoder.inverse_transform([predicted_class])[0]
  l.append(predicted_drug)
print("The Predicted values are: ")
print(l)
# Out:
# 2/2 [==============================] - 0s 8ms/step
# The Predicted values are:
# ['DrugY', 'DrugY', 'DrugY', 'drugX', 'DrugY', 'DrugY', 'DrugY', 'DrugY', 'DrugY', 'drugX', 'DrugY', 'DrugY', 'DrugY', 'DrugY', 'drugX', 'DrugY', 'drugX', 'drugX', 'DrugY', 'DrugY', 'DrugY', 'drugX', 'drugX', 'DrugY', 'DrugY', 'DrugY', 'drugX', 'DrugY', 'DrugY', 'DrugY', 'DrugY', 'DrugY', 'DrugY', 'DrugY', 'drugX', 'DrugY', 'drugX', 'DrugY', 'DrugY', 'DrugY']

# %%
# Comparing predicted with the actual value
comp = pd.DataFrame(Y_test)  # Creating a dataframe
comp['Drug'] = label_encoder.inverse_transform(comp['Drug'])
comp.columns = ['Actual Value']  # Changing the column name
comp['Predicted Value'] = l  # Creating a column based onth prediction
comp
# Out:
#     Actual Value Predicted Value
# 95         drugX           DrugY
# 15         DrugY           DrugY
# 30         drugX           DrugY
# 158        drugC           drugX
# 128        DrugY           DrugY
# 115        DrugY           DrugY
# 69         DrugY           DrugY
# 170        drugX           DrugY
# 174        drugA           DrugY
# 45         drugX           drugX
# 66         drugA           DrugY
# 182        drugX           DrugY
# 165        DrugY           DrugY
# 78         drugA           DrugY
# 186        drugB           drugX
# 177        DrugY           DrugY
# 56         drugB           drugX
# 152        drugX           drugX
# 82         drugC           DrugY
# 68         DrugY           DrugY
# 124        drugB           DrugY
# 16         drugX           drugX
# 148        drugX           drugX
# 93         DrugY           DrugY
# 65         DrugY           DrugY
# 60         DrugY           DrugY
# 84         drugC           drugX
# 67         drugX           DrugY
# 125        DrugY           DrugY
# 132        drugX           DrugY
# 9          DrugY           DrugY
# 18         drugC           DrugY
# 55         drugC           DrugY
# 75         DrugY           DrugY
# 150        drugA           drugX
# 104        DrugY           DrugY
# 135        drugX           drugX
# 137        drugA           DrugY
# 164        DrugY           DrugY
# 76         drugA           DrugY

# %%
y_pred = model.predict([[30, 1, 2, 0, 24.110]])
print(y_pred)
result =  np.argmax(y_pred)
output = ['DrugY', 'drugX', 'drugA', 'drugC', 'drugB']
result
# Out:
# 1/1 [==============================] - 0s 71ms/step
# [[0.92712957 0.00787001 0.01400959 0.00105586 0.04993504]]
# 0

# %%
print(f"Output is: {output[result]}")
# Out:
# Output is: DrugY
